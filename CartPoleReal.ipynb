# %%
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline
import gym
# 動画の描画関数の宣言
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display

def display_frames_as_gif(frames):

    plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0), dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])
    
    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=50)

    anim.save('movie_cartpolereal.mp4')
    display(display_animation(anim, default_mode='loop'))
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\Kota\Anaconda3\envs\rl_env\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
# 定数の設定
ENV = 'CartPole-v0'  # 使用する課題名
NUM_DIZITIZED = 6    # 各状態の離散値への分割数
GAMMA = 0.99  # 時間割引率
ETA = 0.5  # 学習係数
MAX_STEPS = 2000  # 1試行のstep数
NUM_EPISODES = 10000  # 最大試行回数

# %%
class Agent:
    '''CartPoleのエージェントクラスです，棒付き台車そのものになります'''
    
    def __init__(self, num_states, num_actions):
        self.brain = Brain(num_states, num_actions)
        # エージェントが行動を決定するための頭脳を生成
        
    def update_Q_function(self, observation, action, reward, observation_next):
        '''Q関数の更新'''
        self.brain.update_Q_table(
            observation, action, reward, observation_next)
    
    def get_action(self, observation, step):
        '''行動の決定'''
        action = self.brain.decide_action(observation, step)
        return action

# %%
class Brain:
    '''エージェントが持つ脳となるクラスです，Q学習を実行します'''
    
    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions  # CartPoleの行動（右に左に押す）の2を取得
        
        # Qテーブルを作成．行数は状態を分割数^(4変数)にデジタル変換した値，列数は行動数を示す
        self.q_table = np.random.uniform(low=0, high=1, size=(NUM_DIZITIZED**num_states, num_actions))
        
    def bins(self, clip_min, clip_max, num):
        '''観測した状態（連続値）を離散値にデジタル変換する閾値を求める'''
        return np.linspace(clip_min, clip_max, num + 1)[1:-1]
    
    def digitize_state(self, observation):
        '''観測したobservation状態を，離散値に変換する'''
        pole_angle, pole_v = observation
        digitized = [
            #np.digitize(cart_pos, bins=self.bins(-2.4, 2.4, NUM_DIZITIZED)),
            #np.digitize(cart_v, bins=self.bins(-3.0, 3.0, NUM_DIZITIZED)),
            np.digitize(pole_angle, bins=self.bins(-0.5, 0.5, NUM_DIZITIZED)),
            np.digitize(pole_v, bins=self.bins(-2.0, 2.0, NUM_DIZITIZED))]
        return sum([x * (NUM_DIZITIZED**i) for i, x in enumerate(digitized)])
    
    def update_Q_table(self, observation, action, reward, observation_next):
        '''QテーブルをQ学習により更新'''
        state = self.digitize_state(observation)  # 状態を離散化
        state_next = self.digitize_state(observation_next)  # 次の状態を離散化
        Max_Q_next = max(self.q_table[state_next][:])
        self.q_table[state, action] = self.q_table[state, action] + \
            ETA * (reward + GAMMA * Max_Q_next - self.q_table[state, action])
    
    def decide_action(self, observation, episode):
        '''ε-greedy法で徐々に最適行動のみを採用する'''
        state = self.digitize_state(observation)
        epsilon = 0.5 * (1 / (episode + 1))
        
        if epsilon <= np.random.uniform(0, 1):
            action = np.argmax(self.q_table[state][:])
        else:
            action = np.random.choice(self.num_actions)  # 0, 1の行動をランダムに返す
        return action

# %%
class Environment:
    '''CartPoleを実行する環境のクラスです'''
    
    def __init__(self):
        self.env = gym.make(ENV).unwrapped# 実行する課題を設定
        self.env._max_episode_steps = 1000
        self.env._reward_threshold = 995.0
        self.env.masscart = 0.08
        self.env.masspole = 0.01
        self.env.total_mass = self.env.masscart + self.env.masspole
        self.env.length = 0.035
        self.env.polemass_length = (self.env.masspole * self.env.length)
        self.env.force_mag = 0.2
        #self.theta_threshold_radians = 24 * 2 * math.pi / 360
        num_states = 2 #self.env.observation_space.shape[0]  # 課題の状態の数４を取得
        num_actions = self.env.action_space.n  # CartPoleの行動（右に左に押す）の２を取得
        self.agent = Agent(num_states, num_actions)  # 環境内で行動するAgentを生成
    
    def run(self):
        '''実行'''
        complete_episodes = 0  # 195step以上連続で立ち続けた試行数
        is_episode_final = False  # 最終試行フラグ
        frames = []  # 動画用に画像を格納する変数
        
        for episode in range(NUM_EPISODES):  # 試行数分繰り返す
            observation = self.env.reset()  # 環境の初期化
            
            for step in range(MAX_STEPS):  # １エピソードのループ
                
                if is_episode_final is True:  # 最終試行ではframesに各時刻の画像を追加していく
                    frames.append(self.env.render(mode='rgb_array'))
                
                # 行動を求める
                action = self.agent.get_action(observation[2:], episode)
                
                # 行動a_tの実行により，s_{t+1}, r_{t+1}を求める
                observation_next, _, done, _ = self.env.step(action)  # rewardとinfoは使わないので_にする
                
                # 報酬を与える
                if done:  # ステップ数が200経過するか，一定角度に傾くとdoneはtrueになる
                    if step < 995:
                        reward = -1  # 途中でこけたら罰則として報酬-1を与える
                        complete_episodes = 0  # 195step以上連続で立ち続けた試行数をリセット
                    else:
                        reward = 1  # 立ったまま終了時は報酬を１与える
                        complete_episodes += 1  # 連続記録を更新
                else:
                    reward = 0  # 途中の報酬は０
                
                # step+1の状態observation_nextを用いて，Q関数を更新する
                self.agent.update_Q_function(observation[2:], action, reward, observation_next[2:])
                
                # 観測の更新
                observation = observation_next
                
                # 終了時の処理
                if done:
                    print('{0} Episode: Finished after {1} time steps'.format(episode, step + 1))
                    break
                
            if is_episode_final is True:  # 最終試行では動画を保存と描画
                display_frames_as_gif(frames)
                break
                
            if complete_episodes >= 10:  # 10連続成功なら
                print('10回連続成功')
                is_episode_final = True  # 次の試行を描画を行う最終試行とする

# %%
# main
cartpole_env = Environment()
cartpole_env.run()
# Out:
# C:\Users\Kota\Anaconda3\envs\rl_env\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# 0 Episode: Finished after 11 time steps
# 1 Episode: Finished after 7 time steps
# 2 Episode: Finished after 7 time steps
# 3 Episode: Finished after 9 time steps
# 4 Episode: Finished after 10 time steps
# 5 Episode: Finished after 7 time steps
# 6 Episode: Finished after 10 time steps
# 7 Episode: Finished after 13 time steps
# 8 Episode: Finished after 18 time steps
# 9 Episode: Finished after 8 time steps
# 10 Episode: Finished after 7 time steps
# 11 Episode: Finished after 17 time steps
# 12 Episode: Finished after 24 time steps
# 13 Episode: Finished after 9 time steps
# 14 Episode: Finished after 27 time steps
# 15 Episode: Finished after 13 time steps
# 16 Episode: Finished after 10 time steps
# 17 Episode: Finished after 9 time steps
# 18 Episode: Finished after 11 time steps
# 19 Episode: Finished after 17 time steps
# 20 Episode: Finished after 26 time steps
# 21 Episode: Finished after 13 time steps
# 22 Episode: Finished after 6 time steps
# 23 Episode: Finished after 16 time steps
# 24 Episode: Finished after 19 time steps
# 25 Episode: Finished after 16 time steps
# 26 Episode: Finished after 39 time steps
# 27 Episode: Finished after 14 time steps
# 28 Episode: Finished after 32 time steps
# 29 Episode: Finished after 18 time steps
# 30 Episode: Finished after 20 time steps
# 31 Episode: Finished after 14 time steps
# 32 Episode: Finished after 22 time steps
# 33 Episode: Finished after 14 time steps
# 34 Episode: Finished after 18 time steps
# 35 Episode: Finished after 47 time steps
# 36 Episode: Finished after 18 time steps
# 37 Episode: Finished after 32 time steps
# 38 Episode: Finished after 10 time steps
# 39 Episode: Finished after 14 time steps
# 40 Episode: Finished after 23 time steps
# 41 Episode: Finished after 19 time steps
# 42 Episode: Finished after 23 time steps
# 43 Episode: Finished after 27 time steps
# 44 Episode: Finished after 20 time steps
# 45 Episode: Finished after 23 time steps
# 46 Episode: Finished after 23 time steps
# 47 Episode: Finished after 15 time steps
# 48 Episode: Finished after 14 time steps
# 49 Episode: Finished after 31 time steps
# 50 Episode: Finished after 13 time steps
# 51 Episode: Finished after 19 time steps
# 52 Episode: Finished after 16 time steps
# 53 Episode: Finished after 15 time steps
# 54 Episode: Finished after 35 time steps
# 55 Episode: Finished after 18 time steps
# 56 Episode: Finished after 31 time steps
# 57 Episode: Finished after 46 time steps
# 58 Episode: Finished after 16 time steps
# 59 Episode: Finished after 15 time steps
# 60 Episode: Finished after 6 time steps
# 61 Episode: Finished after 23 time steps
# 62 Episode: Finished after 17 time steps
# 63 Episode: Finished after 25 time steps
# 64 Episode: Finished after 29 time steps
# 65 Episode: Finished after 20 time steps
# 66 Episode: Finished after 13 time steps
# 67 Episode: Finished after 72 time steps
# 68 Episode: Finished after 18 time steps
# 69 Episode: Finished after 39 time steps
# 70 Episode: Finished after 10 time steps
# 71 Episode: Finished after 113 time steps
# 72 Episode: Finished after 18 time steps
# 73 Episode: Finished after 19 time steps
# 74 Episode: Finished after 40 time steps
# 75 Episode: Finished after 59 time steps
# 76 Episode: Finished after 9 time steps
# 77 Episode: Finished after 165 time steps
# 78 Episode: Finished after 42 time steps
# 79 Episode: Finished after 60 time steps
# 80 Episode: Finished after 69 time steps
# 81 Episode: Finished after 58 time steps
# 82 Episode: Finished after 128 time steps
# 83 Episode: Finished after 11 time steps
# 84 Episode: Finished after 22 time steps
# 85 Episode: Finished after 16 time steps
# 86 Episode: Finished after 16 time steps
# 87 Episode: Finished after 41 time steps
# 88 Episode: Finished after 40 time steps
# 89 Episode: Finished after 17 time steps
# 90 Episode: Finished after 12 time steps
# 91 Episode: Finished after 30 time steps
# 92 Episode: Finished after 65 time steps
# 93 Episode: Finished after 42 time steps
# 94 Episode: Finished after 18 time steps
# 95 Episode: Finished after 16 time steps
# 96 Episode: Finished after 25 time steps
# 97 Episode: Finished after 61 time steps
# 98 Episode: Finished after 16 time steps
# 99 Episode: Finished after 44 time steps
# 100 Episode: Finished after 69 time steps
# 101 Episode: Finished after 77 time steps
# 102 Episode: Finished after 21 time steps
# 103 Episode: Finished after 14 time steps
# 104 Episode: Finished after 9 time steps
# 105 Episode: Finished after 217 time steps
# 106 Episode: Finished after 76 time steps
# 107 Episode: Finished after 27 time steps
# 108 Episode: Finished after 18 time steps
# 109 Episode: Finished after 34 time steps
# 110 Episode: Finished after 39 time steps
# 111 Episode: Finished after 19 time steps
# 112 Episode: Finished after 100 time steps
# 113 Episode: Finished after 11 time steps
# 114 Episode: Finished after 8 time steps
# 115 Episode: Finished after 7 time steps
# 116 Episode: Finished after 87 time steps
# 117 Episode: Finished after 74 time steps
# 118 Episode: Finished after 17 time steps
# 119 Episode: Finished after 50 time steps
# 120 Episode: Finished after 35 time steps
# 121 Episode: Finished after 27 time steps
# 122 Episode: Finished after 42 time steps
# 123 Episode: Finished after 55 time steps
# 124 Episode: Finished after 33 time steps
# 125 Episode: Finished after 35 time steps
# 126 Episode: Finished after 9 time steps
# 127 Episode: Finished after 27 time steps
# 128 Episode: Finished after 32 time steps
# 129 Episode: Finished after 120 time steps
# 130 Episode: Finished after 13 time steps
# 131 Episode: Finished after 41 time steps
# 132 Episode: Finished after 38 time steps
# 133 Episode: Finished after 93 time steps
# 134 Episode: Finished after 134 time steps
# 135 Episode: Finished after 62 time steps
# 136 Episode: Finished after 29 time steps
# 137 Episode: Finished after 47 time steps
# 138 Episode: Finished after 93 time steps
# 139 Episode: Finished after 59 time steps
# 140 Episode: Finished after 20 time steps
# 141 Episode: Finished after 13 time steps
# 142 Episode: Finished after 38 time steps
# 143 Episode: Finished after 19 time steps
# 144 Episode: Finished after 110 time steps
# 145 Episode: Finished after 50 time steps
# 146 Episode: Finished after 14 time steps
# 147 Episode: Finished after 13 time steps
# 148 Episode: Finished after 8 time steps
# 149 Episode: Finished after 25 time steps
# 150 Episode: Finished after 13 time steps
# 151 Episode: Finished after 6 time steps
# 152 Episode: Finished after 8 time steps
# 153 Episode: Finished after 10 time steps
# 154 Episode: Finished after 8 time steps
# 155 Episode: Finished after 7 time steps
# 156 Episode: Finished after 47 time steps
# 157 Episode: Finished after 46 time steps
# 158 Episode: Finished after 11 time steps
# 159 Episode: Finished after 27 time steps
# 160 Episode: Finished after 18 time steps
# 161 Episode: Finished after 13 time steps
# 162 Episode: Finished after 37 time steps
# 163 Episode: Finished after 66 time steps
# 164 Episode: Finished after 97 time steps
# 165 Episode: Finished after 25 time steps
# 166 Episode: Finished after 37 time steps
# 167 Episode: Finished after 17 time steps
# 168 Episode: Finished after 10 time steps
# 169 Episode: Finished after 82 time steps
# 170 Episode: Finished after 12 time steps
# 171 Episode: Finished after 14 time steps
# 172 Episode: Finished after 107 time steps
# 173 Episode: Finished after 46 time steps
# 174 Episode: Finished after 159 time steps
# 175 Episode: Finished after 27 time steps
# 176 Episode: Finished after 63 time steps
# 177 Episode: Finished after 124 time steps
# 178 Episode: Finished after 12 time steps
# 179 Episode: Finished after 27 time steps
# 180 Episode: Finished after 23 time steps
# 181 Episode: Finished after 35 time steps
# 182 Episode: Finished after 118 time steps
# 183 Episode: Finished after 45 time steps
# 184 Episode: Finished after 71 time steps
# 185 Episode: Finished after 25 time steps
# 186 Episode: Finished after 22 time steps
# 187 Episode: Finished after 54 time steps
# 188 Episode: Finished after 71 time steps
# 189 Episode: Finished after 55 time steps
# 190 Episode: Finished after 39 time steps
# 191 Episode: Finished after 145 time steps
# 192 Episode: Finished after 24 time steps
# 193 Episode: Finished after 18 time steps
# 194 Episode: Finished after 27 time steps
# 195 Episode: Finished after 42 time steps
# 196 Episode: Finished after 46 time steps
# 197 Episode: Finished after 128 time steps
# 198 Episode: Finished after 34 time steps
# 199 Episode: Finished after 168 time steps
# 200 Episode: Finished after 36 time steps
# 201 Episode: Finished after 37 time steps
# 202 Episode: Finished after 184 time steps
# 203 Episode: Finished after 404 time steps
# 204 Episode: Finished after 143 time steps
# 205 Episode: Finished after 29 time steps
# 206 Episode: Finished after 66 time steps
# 207 Episode: Finished after 24 time steps
# 208 Episode: Finished after 12 time steps
# 209 Episode: Finished after 120 time steps
# 210 Episode: Finished after 10 time steps
# 211 Episode: Finished after 37 time steps
# 212 Episode: Finished after 27 time steps
# 213 Episode: Finished after 18 time steps
# 214 Episode: Finished after 46 time steps
# 215 Episode: Finished after 45 time steps
# 216 Episode: Finished after 132 time steps
# 217 Episode: Finished after 143 time steps
# 218 Episode: Finished after 37 time steps
# 219 Episode: Finished after 65 time steps
# 220 Episode: Finished after 319 time steps
# 221 Episode: Finished after 36 time steps
# 222 Episode: Finished after 64 time steps
# 223 Episode: Finished after 6 time steps
# 224 Episode: Finished after 13 time steps
# 225 Episode: Finished after 81 time steps
# 226 Episode: Finished after 41 time steps
# 227 Episode: Finished after 124 time steps
# 228 Episode: Finished after 33 time steps
# 229 Episode: Finished after 19 time steps
# 230 Episode: Finished after 22 time steps
# 231 Episode: Finished after 16 time steps
# 232 Episode: Finished after 37 time steps
# 233 Episode: Finished after 56 time steps
# 234 Episode: Finished after 130 time steps
# 235 Episode: Finished after 49 time steps
# 236 Episode: Finished after 13 time steps
# 237 Episode: Finished after 31 time steps
# 238 Episode: Finished after 15 time steps
# 239 Episode: Finished after 149 time steps
# 240 Episode: Finished after 8 time steps
# 241 Episode: Finished after 19 time steps
# 242 Episode: Finished after 32 time steps
# 243 Episode: Finished after 33 time steps
# 244 Episode: Finished after 12 time steps
# 245 Episode: Finished after 9 time steps
# 246 Episode: Finished after 50 time steps
# 247 Episode: Finished after 80 time steps
# 248 Episode: Finished after 18 time steps
# 249 Episode: Finished after 9 time steps
# 250 Episode: Finished after 66 time steps
# 251 Episode: Finished after 283 time steps
# 252 Episode: Finished after 24 time steps
# 253 Episode: Finished after 8 time steps
# 254 Episode: Finished after 43 time steps
# 255 Episode: Finished after 12 time steps
# 256 Episode: Finished after 15 time steps
# 257 Episode: Finished after 248 time steps
# 258 Episode: Finished after 69 time steps
# 259 Episode: Finished after 28 time steps
# 260 Episode: Finished after 12 time steps
# 261 Episode: Finished after 20 time steps
# 262 Episode: Finished after 25 time steps
# 263 Episode: Finished after 47 time steps
# 264 Episode: Finished after 34 time steps
# 265 Episode: Finished after 63 time steps
# 266 Episode: Finished after 226 time steps
# 267 Episode: Finished after 74 time steps
# 268 Episode: Finished after 93 time steps
# 269 Episode: Finished after 79 time steps
# 270 Episode: Finished after 127 time steps
# 271 Episode: Finished after 124 time steps
# 272 Episode: Finished after 255 time steps
# 273 Episode: Finished after 174 time steps
# 274 Episode: Finished after 67 time steps
# 275 Episode: Finished after 66 time steps
# 276 Episode: Finished after 17 time steps
# 277 Episode: Finished after 34 time steps
# 278 Episode: Finished after 48 time steps
# 279 Episode: Finished after 460 time steps
# 280 Episode: Finished after 23 time steps
# 281 Episode: Finished after 34 time steps
# 282 Episode: Finished after 61 time steps
# 283 Episode: Finished after 84 time steps
# 284 Episode: Finished after 13 time steps
# 285 Episode: Finished after 154 time steps
# 286 Episode: Finished after 11 time steps
# 287 Episode: Finished after 37 time steps
# 288 Episode: Finished after 16 time steps
# 289 Episode: Finished after 12 time steps
# 290 Episode: Finished after 29 time steps
# 291 Episode: Finished after 48 time steps
# 292 Episode: Finished after 36 time steps
# 293 Episode: Finished after 211 time steps
# 294 Episode: Finished after 12 time steps
# 295 Episode: Finished after 239 time steps
# 296 Episode: Finished after 28 time steps
# 297 Episode: Finished after 218 time steps
# 298 Episode: Finished after 162 time steps
# 299 Episode: Finished after 83 time steps
# 300 Episode: Finished after 14 time steps
# 301 Episode: Finished after 27 time steps
# 302 Episode: Finished after 16 time steps
# 303 Episode: Finished after 357 time steps
# 304 Episode: Finished after 42 time steps
# 305 Episode: Finished after 18 time steps
# 306 Episode: Finished after 18 time steps
# 307 Episode: Finished after 53 time steps
# 308 Episode: Finished after 155 time steps
# 309 Episode: Finished after 45 time steps
# 310 Episode: Finished after 10 time steps
# 311 Episode: Finished after 185 time steps
# 312 Episode: Finished after 150 time steps
# 313 Episode: Finished after 116 time steps
# 314 Episode: Finished after 95 time steps
# 315 Episode: Finished after 19 time steps
# 316 Episode: Finished after 29 time steps
# 317 Episode: Finished after 20 time steps
# 318 Episode: Finished after 38 time steps
# 319 Episode: Finished after 30 time steps
# 320 Episode: Finished after 30 time steps
# 321 Episode: Finished after 215 time steps
# 322 Episode: Finished after 57 time steps
# 323 Episode: Finished after 246 time steps
# 324 Episode: Finished after 157 time steps
# 325 Episode: Finished after 85 time steps
# 326 Episode: Finished after 139 time steps
# 327 Episode: Finished after 88 time steps
# 328 Episode: Finished after 241 time steps
# 329 Episode: Finished after 57 time steps
# 330 Episode: Finished after 703 time steps
# 331 Episode: Finished after 123 time steps
# 332 Episode: Finished after 219 time steps
# 333 Episode: Finished after 571 time steps
# 334 Episode: Finished after 34 time steps
# 335 Episode: Finished after 7 time steps
# 336 Episode: Finished after 15 time steps
# 337 Episode: Finished after 36 time steps
# 338 Episode: Finished after 390 time steps
# 339 Episode: Finished after 361 time steps
# 340 Episode: Finished after 34 time steps
# 341 Episode: Finished after 147 time steps
# 342 Episode: Finished after 214 time steps
# 343 Episode: Finished after 20 time steps
# 344 Episode: Finished after 32 time steps
# 345 Episode: Finished after 393 time steps
# 346 Episode: Finished after 529 time steps
# 347 Episode: Finished after 575 time steps
# 348 Episode: Finished after 41 time steps
# 349 Episode: Finished after 79 time steps
# 350 Episode: Finished after 460 time steps
# 351 Episode: Finished after 140 time steps
# 352 Episode: Finished after 14 time steps
# 353 Episode: Finished after 22 time steps
# 354 Episode: Finished after 37 time steps
# 355 Episode: Finished after 17 time steps
# 356 Episode: Finished after 30 time steps
# 357 Episode: Finished after 75 time steps
# 358 Episode: Finished after 42 time steps
# 359 Episode: Finished after 20 time steps
# 360 Episode: Finished after 106 time steps
# 361 Episode: Finished after 319 time steps
# 362 Episode: Finished after 53 time steps
# 363 Episode: Finished after 52 time steps
# 364 Episode: Finished after 19 time steps
# 365 Episode: Finished after 41 time steps
# 366 Episode: Finished after 21 time steps
# 367 Episode: Finished after 43 time steps
# 368 Episode: Finished after 60 time steps
# 369 Episode: Finished after 57 time steps
# 370 Episode: Finished after 16 time steps
# 371 Episode: Finished after 9 time steps
# 372 Episode: Finished after 26 time steps
# 373 Episode: Finished after 23 time steps
# 374 Episode: Finished after 158 time steps
# 375 Episode: Finished after 143 time steps
# 376 Episode: Finished after 44 time steps
# 377 Episode: Finished after 40 time steps
# 378 Episode: Finished after 303 time steps
# 379 Episode: Finished after 892 time steps
# 380 Episode: Finished after 68 time steps
# 381 Episode: Finished after 568 time steps
# 382 Episode: Finished after 19 time steps
# 383 Episode: Finished after 453 time steps
# 384 Episode: Finished after 29 time steps
# 385 Episode: Finished after 8 time steps
# 386 Episode: Finished after 26 time steps
# 387 Episode: Finished after 59 time steps
# 388 Episode: Finished after 453 time steps
# 389 Episode: Finished after 889 time steps
# 390 Episode: Finished after 388 time steps
# 391 Episode: Finished after 9 time steps
# 392 Episode: Finished after 564 time steps
# 393 Episode: Finished after 62 time steps
# 394 Episode: Finished after 92 time steps
# 395 Episode: Finished after 84 time steps
# 396 Episode: Finished after 179 time steps
# 397 Episode: Finished after 223 time steps
# 398 Episode: Finished after 32 time steps
# 399 Episode: Finished after 37 time steps
# 400 Episode: Finished after 275 time steps
# 401 Episode: Finished after 242 time steps
# 402 Episode: Finished after 463 time steps
# 403 Episode: Finished after 787 time steps
# 404 Episode: Finished after 88 time steps
# 405 Episode: Finished after 515 time steps
# 406 Episode: Finished after 176 time steps
# 407 Episode: Finished after 769 time steps
# 408 Episode: Finished after 607 time steps
# 409 Episode: Finished after 1288 time steps
# 410 Episode: Finished after 689 time steps
# 411 Episode: Finished after 646 time steps
# 412 Episode: Finished after 181 time steps
# 413 Episode: Finished after 223 time steps
# 414 Episode: Finished after 490 time steps
# 415 Episode: Finished after 780 time steps
# 416 Episode: Finished after 1080 time steps
# 417 Episode: Finished after 406 time steps
# 418 Episode: Finished after 702 time steps
# 419 Episode: Finished after 762 time steps
# 420 Episode: Finished after 123 time steps
# 421 Episode: Finished after 156 time steps
# 422 Episode: Finished after 16 time steps
# 423 Episode: Finished after 344 time steps
# 424 Episode: Finished after 109 time steps
# 425 Episode: Finished after 523 time steps
# 426 Episode: Finished after 475 time steps
# 427 Episode: Finished after 337 time steps
# 428 Episode: Finished after 29 time steps
# 429 Episode: Finished after 19 time steps
# 430 Episode: Finished after 16 time steps
# 431 Episode: Finished after 21 time steps
# 432 Episode: Finished after 18 time steps
# 433 Episode: Finished after 8 time steps
# 434 Episode: Finished after 32 time steps
# 435 Episode: Finished after 15 time steps
# 436 Episode: Finished after 12 time steps
# 437 Episode: Finished after 1512 time steps
# 438 Episode: Finished after 440 time steps
# 439 Episode: Finished after 443 time steps
# 440 Episode: Finished after 1246 time steps
# 441 Episode: Finished after 52 time steps
# 442 Episode: Finished after 34 time steps
# 443 Episode: Finished after 557 time steps
# 444 Episode: Finished after 12 time steps
# 445 Episode: Finished after 27 time steps
# 446 Episode: Finished after 16 time steps
# 447 Episode: Finished after 95 time steps
# 448 Episode: Finished after 39 time steps
# 449 Episode: Finished after 26 time steps
# 450 Episode: Finished after 18 time steps
# 451 Episode: Finished after 14 time steps
# 452 Episode: Finished after 9 time steps
# 453 Episode: Finished after 27 time steps
# 454 Episode: Finished after 26 time steps
# 455 Episode: Finished after 33 time steps
# 456 Episode: Finished after 59 time steps
# 457 Episode: Finished after 35 time steps
# 458 Episode: Finished after 679 time steps
# 459 Episode: Finished after 44 time steps
# 460 Episode: Finished after 29 time steps
# 461 Episode: Finished after 30 time steps
# 462 Episode: Finished after 17 time steps
# 463 Episode: Finished after 18 time steps
# 464 Episode: Finished after 14 time steps
# 465 Episode: Finished after 66 time steps
# 466 Episode: Finished after 73 time steps
# 467 Episode: Finished after 34 time steps
# 468 Episode: Finished after 42 time steps
# 469 Episode: Finished after 91 time steps
# 470 Episode: Finished after 77 time steps
# 471 Episode: Finished after 40 time steps
# 472 Episode: Finished after 130 time steps
# 473 Episode: Finished after 298 time steps
# 474 Episode: Finished after 63 time steps
# 475 Episode: Finished after 460 time steps
# 476 Episode: Finished after 416 time steps
# 477 Episode: Finished after 356 time steps
# 478 Episode: Finished after 18 time steps
# 479 Episode: Finished after 10 time steps
# 480 Episode: Finished after 17 time steps
# 481 Episode: Finished after 30 time steps
# 482 Episode: Finished after 22 time steps
# 483 Episode: Finished after 73 time steps
# 484 Episode: Finished after 51 time steps
# 485 Episode: Finished after 22 time steps
# 486 Episode: Finished after 34 time steps
# 487 Episode: Finished after 27 time steps
# 488 Episode: Finished after 23 time steps
# 489 Episode: Finished after 51 time steps
# 490 Episode: Finished after 30 time steps
# 491 Episode: Finished after 11 time steps
# 492 Episode: Finished after 19 time steps
# 493 Episode: Finished after 12 time steps
# 494 Episode: Finished after 55 time steps
# 495 Episode: Finished after 44 time steps
# 496 Episode: Finished after 19 time steps
# 497 Episode: Finished after 16 time steps
# 498 Episode: Finished after 19 time steps
# 499 Episode: Finished after 14 time steps
# 500 Episode: Finished after 19 time steps
# 501 Episode: Finished after 65 time steps
# 502 Episode: Finished after 13 time steps
# 503 Episode: Finished after 11 time steps
# 504 Episode: Finished after 13 time steps
# 505 Episode: Finished after 8 time steps
# 506 Episode: Finished after 14 time steps
# 507 Episode: Finished after 25 time steps
# 508 Episode: Finished after 17 time steps
# 509 Episode: Finished after 13 time steps
# 510 Episode: Finished after 22 time steps
# 511 Episode: Finished after 22 time steps
# 512 Episode: Finished after 8 time steps
# 513 Episode: Finished after 15 time steps
# 514 Episode: Finished after 18 time steps
# 515 Episode: Finished after 9 time steps
# 516 Episode: Finished after 12 time steps
# 517 Episode: Finished after 11 time steps
# 518 Episode: Finished after 36 time steps
# 519 Episode: Finished after 8 time steps
# 520 Episode: Finished after 24 time steps
# 521 Episode: Finished after 23 time steps
# 522 Episode: Finished after 15 time steps
# 523 Episode: Finished after 42 time steps
# 524 Episode: Finished after 57 time steps
# 525 Episode: Finished after 29 time steps
# 526 Episode: Finished after 9 time steps
# 527 Episode: Finished after 101 time steps
# 528 Episode: Finished after 57 time steps
# 529 Episode: Finished after 31 time steps
# 530 Episode: Finished after 70 time steps
# 531 Episode: Finished after 43 time steps
# 532 Episode: Finished after 29 time steps
# 533 Episode: Finished after 40 time steps
# 534 Episode: Finished after 51 time steps
# 535 Episode: Finished after 19 time steps
# 536 Episode: Finished after 21 time steps
# 537 Episode: Finished after 22 time steps
# 538 Episode: Finished after 59 time steps
# 539 Episode: Finished after 36 time steps
# 540 Episode: Finished after 41 time steps
# 541 Episode: Finished after 19 time steps
# 542 Episode: Finished after 13 time steps
# 543 Episode: Finished after 89 time steps
# 544 Episode: Finished after 47 time steps
# 545 Episode: Finished after 41 time steps
# 546 Episode: Finished after 7 time steps
# 547 Episode: Finished after 57 time steps
# 548 Episode: Finished after 49 time steps
# 549 Episode: Finished after 128 time steps
# 550 Episode: Finished after 23 time steps
# 551 Episode: Finished after 42 time steps
# 552 Episode: Finished after 21 time steps
# 553 Episode: Finished after 7 time steps
# 554 Episode: Finished after 45 time steps
# 555 Episode: Finished after 20 time steps
# 556 Episode: Finished after 44 time steps
# 557 Episode: Finished after 195 time steps
# 558 Episode: Finished after 61 time steps
# 559 Episode: Finished after 46 time steps
# 560 Episode: Finished after 490 time steps
# 561 Episode: Finished after 56 time steps
# 562 Episode: Finished after 40 time steps
# 563 Episode: Finished after 36 time steps
# 564 Episode: Finished after 54 time steps
# 565 Episode: Finished after 37 time steps
# 566 Episode: Finished after 22 time steps
# 567 Episode: Finished after 29 time steps
# 568 Episode: Finished after 19 time steps
# 569 Episode: Finished after 481 time steps
# 570 Episode: Finished after 452 time steps
# 571 Episode: Finished after 553 time steps
# 572 Episode: Finished after 1214 time steps
# 573 Episode: Finished after 115 time steps
# 574 Episode: Finished after 855 time steps
# 575 Episode: Finished after 904 time steps
# 576 Episode: Finished after 483 time steps
# 577 Episode: Finished after 107 time steps
# 578 Episode: Finished after 21 time steps
# 579 Episode: Finished after 11 time steps
# 580 Episode: Finished after 50 time steps
# 581 Episode: Finished after 18 time steps
# 582 Episode: Finished after 10 time steps
# 583 Episode: Finished after 11 time steps
# 584 Episode: Finished after 37 time steps
# 585 Episode: Finished after 137 time steps
# 586 Episode: Finished after 123 time steps
# 587 Episode: Finished after 1171 time steps
# 588 Episode: Finished after 1185 time steps
# 589 Episode: Finished after 263 time steps
# 590 Episode: Finished after 1024 time steps
# 591 Episode: Finished after 1728 time steps
# 592 Episode: Finished after 59 time steps
# 593 Episode: Finished after 216 time steps
# 594 Episode: Finished after 16 time steps
# 595 Episode: Finished after 54 time steps
# 596 Episode: Finished after 91 time steps
# 597 Episode: Finished after 47 time steps
# 598 Episode: Finished after 30 time steps
# 599 Episode: Finished after 23 time steps
# 600 Episode: Finished after 60 time steps
# 601 Episode: Finished after 23 time steps
# 602 Episode: Finished after 16 time steps
# 603 Episode: Finished after 11 time steps
# 604 Episode: Finished after 357 time steps
# 605 Episode: Finished after 423 time steps
# 606 Episode: Finished after 1029 time steps
# 607 Episode: Finished after 766 time steps
# 608 Episode: Finished after 1364 time steps
# 611 Episode: Finished after 1931 time steps
# 612 Episode: Finished after 1255 time steps
# 613 Episode: Finished after 1168 time steps
# 615 Episode: Finished after 1418 time steps
# 616 Episode: Finished after 956 time steps
# 617 Episode: Finished after 418 time steps
# 618 Episode: Finished after 1038 time steps
# 619 Episode: Finished after 471 time steps
# 620 Episode: Finished after 367 time steps
# 621 Episode: Finished after 256 time steps
# 622 Episode: Finished after 294 time steps
# 623 Episode: Finished after 89 time steps
# 624 Episode: Finished after 155 time steps
# 625 Episode: Finished after 146 time steps
# 626 Episode: Finished after 148 time steps
# 627 Episode: Finished after 245 time steps
# 628 Episode: Finished after 260 time steps
# 629 Episode: Finished after 299 time steps
# 630 Episode: Finished after 161 time steps
# 631 Episode: Finished after 38 time steps
# 632 Episode: Finished after 57 time steps
# 633 Episode: Finished after 59 time steps
# 634 Episode: Finished after 49 time steps
# 635 Episode: Finished after 27 time steps
# 636 Episode: Finished after 53 time steps
# 637 Episode: Finished after 57 time steps
# 638 Episode: Finished after 28 time steps
# 639 Episode: Finished after 12 time steps
# 640 Episode: Finished after 25 time steps
# 641 Episode: Finished after 15 time steps
# 642 Episode: Finished after 82 time steps
# 643 Episode: Finished after 501 time steps
# 644 Episode: Finished after 501 time steps
# 645 Episode: Finished after 665 time steps
# 646 Episode: Finished after 449 time steps
# 647 Episode: Finished after 361 time steps
# 648 Episode: Finished after 20 time steps
# 649 Episode: Finished after 161 time steps
# 650 Episode: Finished after 56 time steps
# 651 Episode: Finished after 679 time steps
# 652 Episode: Finished after 64 time steps
# 653 Episode: Finished after 57 time steps
# 654 Episode: Finished after 43 time steps
# 655 Episode: Finished after 933 time steps
# 656 Episode: Finished after 1491 time steps
# 657 Episode: Finished after 1740 time steps
# 658 Episode: Finished after 1151 time steps
# 659 Episode: Finished after 8 time steps
# 660 Episode: Finished after 28 time steps
# 661 Episode: Finished after 7 time steps
# 662 Episode: Finished after 216 time steps
# 663 Episode: Finished after 642 time steps
# 664 Episode: Finished after 139 time steps
# 665 Episode: Finished after 1260 time steps
# 666 Episode: Finished after 659 time steps
# 667 Episode: Finished after 144 time steps
# 668 Episode: Finished after 704 time steps
# 669 Episode: Finished after 1011 time steps
# 670 Episode: Finished after 1255 time steps
# 671 Episode: Finished after 970 time steps
# 672 Episode: Finished after 1243 time steps
# 673 Episode: Finished after 713 time steps
# 674 Episode: Finished after 556 time steps
# 675 Episode: Finished after 502 time steps
# 676 Episode: Finished after 287 time steps
# 677 Episode: Finished after 338 time steps
# 678 Episode: Finished after 319 time steps
# 679 Episode: Finished after 41 time steps
# 680 Episode: Finished after 48 time steps
# 681 Episode: Finished after 194 time steps
# 682 Episode: Finished after 176 time steps
# 683 Episode: Finished after 49 time steps
# 684 Episode: Finished after 138 time steps
# 685 Episode: Finished after 32 time steps
# 686 Episode: Finished after 55 time steps
# 687 Episode: Finished after 358 time steps
# 688 Episode: Finished after 41 time steps
# 689 Episode: Finished after 17 time steps
# 690 Episode: Finished after 18 time steps
# 691 Episode: Finished after 23 time steps
# 692 Episode: Finished after 12 time steps
# 693 Episode: Finished after 18 time steps
# 694 Episode: Finished after 50 time steps
# 695 Episode: Finished after 415 time steps
# 696 Episode: Finished after 120 time steps
# 697 Episode: Finished after 385 time steps
# 698 Episode: Finished after 1480 time steps
# 699 Episode: Finished after 961 time steps
# 700 Episode: Finished after 412 time steps
# 701 Episode: Finished after 24 time steps
# 702 Episode: Finished after 18 time steps
# 703 Episode: Finished after 335 time steps
# 704 Episode: Finished after 300 time steps
# 705 Episode: Finished after 448 time steps
# 706 Episode: Finished after 417 time steps
# 707 Episode: Finished after 11 time steps
# 708 Episode: Finished after 16 time steps
# 709 Episode: Finished after 15 time steps
# 710 Episode: Finished after 11 time steps
# 711 Episode: Finished after 41 time steps
# 712 Episode: Finished after 13 time steps
# 713 Episode: Finished after 428 time steps
# 714 Episode: Finished after 1001 time steps
# 715 Episode: Finished after 603 time steps
# 716 Episode: Finished after 1109 time steps
# 717 Episode: Finished after 758 time steps
# 719 Episode: Finished after 1445 time steps
# 722 Episode: Finished after 589 time steps
# 723 Episode: Finished after 776 time steps
# 724 Episode: Finished after 63 time steps
# 725 Episode: Finished after 494 time steps
# 726 Episode: Finished after 415 time steps
# 727 Episode: Finished after 58 time steps
# 728 Episode: Finished after 213 time steps
# 729 Episode: Finished after 667 time steps
# 730 Episode: Finished after 28 time steps
# 731 Episode: Finished after 380 time steps
# 732 Episode: Finished after 408 time steps
# 733 Episode: Finished after 363 time steps
# 734 Episode: Finished after 394 time steps
# 735 Episode: Finished after 346 time steps
# 736 Episode: Finished after 442 time steps
# 737 Episode: Finished after 442 time steps
# 738 Episode: Finished after 461 time steps
# 739 Episode: Finished after 371 time steps
# 740 Episode: Finished after 51 time steps
# 741 Episode: Finished after 83 time steps
# 742 Episode: Finished after 30 time steps
# 743 Episode: Finished after 63 time steps
# 744 Episode: Finished after 324 time steps
# 745 Episode: Finished after 490 time steps
# 746 Episode: Finished after 361 time steps
# 747 Episode: Finished after 406 time steps
# 748 Episode: Finished after 399 time steps
# 749 Episode: Finished after 260 time steps
# 750 Episode: Finished after 35 time steps
# 751 Episode: Finished after 42 time steps
# 752 Episode: Finished after 22 time steps
# 753 Episode: Finished after 8 time steps
# 754 Episode: Finished after 13 time steps
# 755 Episode: Finished after 17 time steps
# 756 Episode: Finished after 450 time steps
# 757 Episode: Finished after 819 time steps
# 758 Episode: Finished after 19 time steps
# 759 Episode: Finished after 350 time steps
# 760 Episode: Finished after 9 time steps
# 761 Episode: Finished after 362 time steps
# 762 Episode: Finished after 50 time steps
# 763 Episode: Finished after 56 time steps
# 764 Episode: Finished after 56 time steps
# 765 Episode: Finished after 418 time steps
# 766 Episode: Finished after 483 time steps
# 767 Episode: Finished after 103 time steps
# 768 Episode: Finished after 298 time steps
# 769 Episode: Finished after 26 time steps
# 770 Episode: Finished after 36 time steps
# 771 Episode: Finished after 28 time steps
# 772 Episode: Finished after 22 time steps
# 773 Episode: Finished after 1126 time steps
# 774 Episode: Finished after 917 time steps
# 775 Episode: Finished after 21 time steps
# 776 Episode: Finished after 22 time steps
# 777 Episode: Finished after 7 time steps
# 778 Episode: Finished after 9 time steps
# 779 Episode: Finished after 52 time steps
# 780 Episode: Finished after 30 time steps
# 781 Episode: Finished after 47 time steps
# 782 Episode: Finished after 52 time steps
# 783 Episode: Finished after 75 time steps
# 784 Episode: Finished after 51 time steps
# 785 Episode: Finished after 22 time steps
# 786 Episode: Finished after 478 time steps
# 787 Episode: Finished after 495 time steps
# 788 Episode: Finished after 19 time steps
# 789 Episode: Finished after 24 time steps
# 790 Episode: Finished after 26 time steps
# 791 Episode: Finished after 26 time steps
# 792 Episode: Finished after 52 time steps
# 793 Episode: Finished after 505 time steps
# 794 Episode: Finished after 409 time steps
# 795 Episode: Finished after 306 time steps
# 796 Episode: Finished after 12 time steps
# 797 Episode: Finished after 15 time steps
# 798 Episode: Finished after 380 time steps
# 799 Episode: Finished after 381 time steps
# 800 Episode: Finished after 327 time steps
# 801 Episode: Finished after 445 time steps
# 802 Episode: Finished after 115 time steps
# 803 Episode: Finished after 45 time steps
# 804 Episode: Finished after 18 time steps
# 805 Episode: Finished after 21 time steps
# 806 Episode: Finished after 386 time steps
# 807 Episode: Finished after 486 time steps
# 808 Episode: Finished after 165 time steps
# 809 Episode: Finished after 363 time steps
# 810 Episode: Finished after 346 time steps
# 811 Episode: Finished after 685 time steps
# 812 Episode: Finished after 661 time steps
# 814 Episode: Finished after 37 time steps
# 815 Episode: Finished after 995 time steps
# 816 Episode: Finished after 1821 time steps
# 817 Episode: Finished after 881 time steps
# 818 Episode: Finished after 22 time steps
# 819 Episode: Finished after 1024 time steps
# 820 Episode: Finished after 1617 time steps
# 822 Episode: Finished after 1907 time steps
# 823 Episode: Finished after 1030 time steps
# 824 Episode: Finished after 1895 time steps
# 825 Episode: Finished after 1055 time steps
# 826 Episode: Finished after 1601 time steps
# 828 Episode: Finished after 1939 time steps
# 830 Episode: Finished after 1326 time steps
# 831 Episode: Finished after 1243 time steps
# 10回連続成功
# 832 Episode: Finished after 902 time steps
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgSOIFOKVPJIEPKYON">
#     <br>
#     <input id="_anim_sliderSOIFOKVPJIEPKYON" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animSOIFOKVPJIEPKYON.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animSOIFOKVPJIEPKYON.slower()">&#8211;</button>
#     <button onclick="animSOIFOKVPJIEPKYON.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animSOIFOKVPJIEPKYON.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animSOIFOKVPJIEPKYON.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animSOIFOKVPJIEPKYON.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animSOIFOKVPJIEPKYON.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animSOIFOKVPJIEPKYON.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animSOIFOKVPJIEPKYON.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animSOIFOKVPJIEPKYON.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectSOIFOKVPJIEPKYON" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgSOIFOKVPJIEPKYON";
#     var slider_id = "_anim_sliderSOIFOKVPJIEPKYON";
#     var loop_select_id = "_anim_loop_selectSOIFOKVPJIEPKYON";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6

# %%
cartpole_env.env.masscart
# Out:
# 0.08

# %%
env = gym.make('CartPole-v0').env
observation = env.reset()

# %%
observation
# Out:
# array([-0.01370815, -0.01388248,  0.02675794, -0.04801136])

# %%
50**2
# Out:
# 2500

# %%
q_table=cartpole_env.agent.brain.q_table

# %%
cartpole_env.agent.brain.digitize_state([-0.5,1.334])
# Out:
# 30

# %%
q_table_d=np.argmax(q_table, axis=1)

# %%
print(q_table_d)
# Out:
# [ 5 14 19  3  3  5  7 20 20  2 16 18  6  1 19 19  6  4  5 18 13  8 10  4
#   4 11 10  7  0  4 15 13  2  0  3 14]

# %%
/10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-1b5eceb6e8df> in <module>
# ----> 1 10()
#
# TypeError: 'int' object is not callable

# %%
a=-0.50
for i in range(10):
    a += (1.1/10)
    print(a)

# %%
for i in range(-0.5,0.5,100):
    cartpole_env.agent.brain.digitize_state([i,0])

# %%
np.savetxt('q_table23.csv',q_table_d,delimiter=',')

# %%
self.total_mass = (self.masspole + self.masscart)

# %%
cartpole_env.env.total_mass

# %%
cartpole_env.env.total_mass = (cartpole_env.env.masspole + cartpole_env.env.masscart)

# %%
cartpole_env.env.total_mass

# %%
cartpole_env.env.polemass_length

# %%
cartpole_env.env.polemass_length = cartpole_env.env.masspole * cartpole_env.env.length

# %%
cartpole_env.env.polemass_length

# %%
cartpole_env.env.force_mag
